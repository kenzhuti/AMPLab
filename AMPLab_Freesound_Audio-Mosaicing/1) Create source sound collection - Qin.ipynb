# %% [markdown]
# # 1) Create source sound collection
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
# Essentia
# !pip install essentia
# Freesound-python
# !pip install git+https://github.com/mtg/freesound-python.git
# Mount drive and cd to notebook folder
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# DEPRECATION: Loading egg at /Users/qinliu/anaconda3/lib/python3.11/site-packages/freesound_python-1.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: essentia in /Users/qinliu/anaconda3/lib/python3.11/site-packages (2.1b6.dev1110)
# Requirement already satisfied: numpy>=1.8.2 in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from essentia) (1.24.3)
# Requirement already satisfied: six in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from essentia) (1.16.0)
# Requirement already satisfied: pyyaml in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from essentia) (6.0.1)
# DEPRECATION: Loading egg at /Users/qinliu/anaconda3/lib/python3.11/site-packages/freesound_python-1.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting git+https://github.com/mtg/freesound-python.git
#   Cloning https://github.com/mtg/freesound-python.git to /private/var/folders/vz/_sbkt1_95_jdlv4y0hb6db100000gn/T/pip-req-build-2375gdir
#   Running command git clone --filter=blob:none --quiet https://github.com/mtg/freesound-python.git /private/var/folders/vz/_sbkt1_95_jdlv4y0hb6db100000gn/T/pip-req-build-2375gdir
#   Resolved https://github.com/mtg/freesound-python.git to commit 5be99a3689d17303c01cb122bbb0d5a96eba04f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>2.27 in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from freesound-python==1.1) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>2.27->freesound-python==1.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>2.27->freesound-python==1.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>2.27->freesound-python==1.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qinliu/anaconda3/lib/python3.11/site-packages (from requests<3.0,>2.27->freesound-python==1.1) (2023.11.17)

# %%
import os
import pandas as pd
import numpy as np
import sys
sys.path.append('/Users/qinliu/Postgraduate/Master/MTG-Audio_Signal_Processing/freesound-python/')  # directory were you installed the freesound-python repository
import freesound
from IPython.display import display

FREESOUND_API_KEY = 'qPiYCsYNsQK0FKgX0j5zJo06nuMKZmvNpnx9Rpqe'  # Please replace by your own Freesound API key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME_BREAK = 'dataframe_break.csv'  # File where we'll store the metadata of our sounds collection
DATAFRAME_FILENAME_PIANO = 'dataframe_piano.csv'
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 1,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def make_pandas_record(sound):
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    del record['id']
    record['path'] = "files/" + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %% [markdown]
# # 1. Break Beat Sound Collection

# %%
# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
freesound_queries = [
    # idea is for the zaps to be lower drum kicks
    # idea for snare to be glass smash
    {
        'query': 'bass',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'sub',
        'filter': 'duration:[0 TO 2]',
        'num_results': 20, 
    }, 
    {
        'query': '303',
        'filter': 'duration:[0 TO 2]',
        'num_results': 20, 
    },
    {
        'query': 'clap',
        'filter': 'duration:[0 TO 2]',
        'num_results': 20, 
    }
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')
    
# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME_BREAK)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME_BREAK))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 383560 [1/80]
# Downloading sound with id 51513 [2/80]
# Downloading sound with id 83253 [3/80]
# Downloading sound with id 51498 [4/80]
# Downloading sound with id 288881 [5/80]
# Downloading sound with id 144150 [6/80]
# Downloading sound with id 717726 [7/80]
# Downloading sound with id 616675 [8/80]
# Downloading sound with id 632023 [9/80]
# Downloading sound with id 81957 [10/80]
# Downloading sound with id 18096 [11/80]
# Downloading sound with id 4457 [12/80]
# Downloading sound with id 3523 [13/80]
# Downloading sound with id 21587 [14/80]
# Downloading sound with id 172234 [15/80]
# Downloading sound with id 75229 [16/80]
# Downloading sound with id 418919 [17/80]
# Downloading sound with id 206134 [18/80]
# Downloading sound with id 530224 [19/80]
# Downloading sound with id 706088 [20/80]
# Downloading sound with id 145649 [21/80]
# Downloading sound with id 436551 [22/80]
# Downloading sound with id 83546 [23/80]
# Downloading sound with id 201748 [24/80]
# Downloading sound with id 239513 [25/80]
# Downloading sound with id 391400 [26/80]
# Downloading sound with id 424023 [27/80]
# Downloading sound with id 21587 [28/80]
# Downloading sound with id 194174 [29/80]
# Downloading sound with id 268608 [30/80]
# Downloading sound with id 59538 [31/80]
# Downloading sound with id 231545 [32/80]
# Downloading sound with id 201526 [33/80]
# Downloading sound with id 171312 [34/80]
# Downloading sound with id 487269 [35/80]
# Downloading sound with id 708792 [36/80]
# Downloading sound with id 59537 [37/80]
# Downloading sound with id 59539 [38/80]
# Downloading sound with id 59541 [39/80]
# Downloading sound with id 63138 [40/80]
# Downloading sound with id 418611 [41/80]
# Downloading sound with id 450852 [42/80]
# Downloading sound with id 89075 [43/80]
# Downloading sound with id 50431 [44/80]
# Downloading sound with id 50482 [45/80]
# Downloading sound with id 95390 [46/80]
# Downloading sound with id 156284 [47/80]
# Downloading sound with id 612194 [48/80]
# Downloading sound with id 28350 [49/80]
# Downloading sound with id 128532 [50/80]
# Downloading sound with id 935 [51/80]
# Downloading sound with id 8523 [52/80]
# Downloading sound with id 32289 [53/80]
# Downloading sound with id 32291 [54/80]
# Downloading sound with id 32279 [55/80]
# Downloading sound with id 585287 [56/80]
# Downloading sound with id 584956 [57/80]
# Downloading sound with id 962 [58/80]
# Downloading sound with id 9345 [59/80]
# Downloading sound with id 43366 [60/80]
# Downloading sound with id 695704 [61/80]
# Downloading sound with id 701126 [62/80]
# Downloading sound with id 384138 [63/80]
# Downloading sound with id 513419 [64/80]
# Downloading sound with id 383012 [65/80]
# Downloading sound with id 639138 [66/80]
# Downloading sound with id 195475 [67/80]
# Downloading sound with id 131333 [68/80]
# Downloading sound with id 463686 [69/80]
# Downloading sound with id 609084 [70/80]
# Downloading sound with id 404545 [71/80]
# Downloading sound with id 561090 [72/80]
# Downloading sound with id 561111 [73/80]
# Downloading sound with id 561560 [74/80]
# Downloading sound with id 493706 [75/80]
# Downloading sound with id 541279 [76/80]
# Downloading sound with id 579138 [77/80]
# Downloading sound with id 341593 [78/80]
# Downloading sound with id 537735 [79/80]
# Downloading sound with id 593219 [80/80]
# Saved DataFrame with 80 entries! dataframe_break.csv
#                                  name         username  \
# 0     Standup_Bass_Stop_Finger_F4.wav          pjcohen
# 1           SID-ResBass-short-C#4.wav          supadoh
# 2                       BASS 0209.wav            zgump
# 3           SID-ResBass-short-A#1.wav          supadoh
# 4                   ElectroBass13.wav          gellski
# ..                                ...              ...
# 75    [Drums] Unsliced Live Claps 000      waveplaySFX
# 76  Clap at One Church Corridor 4.wav          jonsept
# 77                           clap.wav             dpsa
# 78                            Clap 01  steeltowngaming
# 79                  CLAP KORT FIX.wav           ilip33
#
#                                               license  \
# 0   http://creativecommons.org/publicdomain/zero/1.0/
# 1   http://creativecommons.org/licenses/sampling+/...
# 2   http://creativecommons.org/publicdomain/zero/1.0/
# 3   http://creativecommons.org/licenses/sampling+/...
# 4         http://creativecommons.org/licenses/by/3.0/
# ..                                                ...
# 75  http://creativecommons.org/publicdomain/zero/1.0/
# 76  http://creativecommons.org/publicdomain/zero/1.0/
# 77        http://creativecommons.org/licenses/by/3.0/
# 78  http://creativecommons.org/publicdomain/zero/1.0/
# 79  http://creativecommons.org/publicdomain/zero/1.0/
#
#                                                  tags  freesound_id  \
# 0   [Stereo, Bass, Instrument, Double, Plucked, St...        383560
# 1                                    [bass, c64, sid]         51513
# 2                                              [bass]         83253
# 3                                    [bass, c64, sid]         51498
# 4                  [reversed, hard, bass, distortion]        288881
# ..                                                ...           ...
# 75  [live, recording, recorded, sliced, record, un...        541279
# 76  [atmosphere, room, echo, ambience, bang, atmos...        579138
# 77                                [sound, dpsa, clap]        341593
# 78                [clapping, hands, slap, clap, hand]        537735
# 79                                  [snap, pop, clap]        593219
#
#                             path
# 0     files/383560_394391-hq.ogg
# 1      files/51513_610202-hq.ogg
# 2      files/83253_377011-hq.ogg
# 3      files/51498_610202-hq.ogg
# 4    files/288881_1471115-hq.ogg
# ..                           ...
# 75   files/541279_1676145-hq.ogg
# 76   files/579138_4185768-hq.ogg
# 77   files/341593_5871007-hq.ogg
# 78  files/537735_11976230-hq.ogg
# 79   files/593219_8407837-hq.ogg
#
# [80 rows x 6 columns]

# %% [markdown]
# # 2. Piano Source Collection

# %%
freesound_queries = [
    # idea is for the zaps to be lower drum kicks
    # idea for snare to be glass smash
    {
        'query': 'JX-8P',
        'filter': None,
        'num_results': 800, 
    }
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')
    
# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME_PIANO)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME_PIANO))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 309684 [1/150]
# Downloading sound with id 307802 [2/150]
# Downloading sound with id 308950 [3/150]
# Downloading sound with id 308829 [4/150]
# Downloading sound with id 308411 [5/150]
# Downloading sound with id 309962 [6/150]
# Downloading sound with id 309795 [7/150]
# Downloading sound with id 307868 [8/150]
# Downloading sound with id 308117 [9/150]
# Downloading sound with id 308426 [10/150]
# Downloading sound with id 309852 [11/150]
# Downloading sound with id 309976 [12/150]
# Downloading sound with id 308299 [13/150]
# Downloading sound with id 309731 [14/150]
# Downloading sound with id 307918 [15/150]
# Downloading sound with id 307979 [16/150]
# Downloading sound with id 308237 [17/150]
# Downloading sound with id 20372 [18/150]
# Downloading sound with id 135144 [19/150]
# Downloading sound with id 135166 [20/150]
# Downloading sound with id 3501 [21/150]
# Downloading sound with id 344922 [22/150]
# Downloading sound with id 307475 [23/150]
# Downloading sound with id 306105 [24/150]
# Downloading sound with id 307089 [25/150]
# Downloading sound with id 307350 [26/150]
# Downloading sound with id 307434 [27/150]
# Downloading sound with id 306795 [28/150]
# Downloading sound with id 306173 [29/150]
# Downloading sound with id 306286 [30/150]
# Downloading sound with id 305999 [31/150]
# Downloading sound with id 306214 [32/150]
# Downloading sound with id 306387 [33/150]
# Downloading sound with id 306489 [34/150]
# Downloading sound with id 306530 [35/150]
# Downloading sound with id 306596 [36/150]
# Downloading sound with id 306654 [37/150]
# Downloading sound with id 306863 [38/150]
# Downloading sound with id 307015 [39/150]
# Downloading sound with id 307553 [40/150]
# Downloading sound with id 307791 [41/150]
# Downloading sound with id 306456 [42/150]
# Downloading sound with id 306975 [43/150]
# Downloading sound with id 307199 [44/150]
# Downloading sound with id 307245 [45/150]
# Downloading sound with id 307288 [46/150]
# Downloading sound with id 307673 [47/150]
# Downloading sound with id 306025 [48/150]
# Downloading sound with id 307139 [49/150]
# Downloading sound with id 307726 [50/150]
# Downloading sound with id 306226 [51/150]
# Downloading sound with id 306725 [52/150]
# Downloading sound with id 307360 [53/150]
# Downloading sound with id 307601 [54/150]
# Downloading sound with id 710312 [55/150]
# Downloading sound with id 648961 [56/150]
# Downloading sound with id 31119 [57/150]
# Downloading sound with id 31131 [58/150]
# Downloading sound with id 31132 [59/150]
# Downloading sound with id 264021 [60/150]
# Downloading sound with id 264022 [61/150]
# Downloading sound with id 264025 [62/150]
# Downloading sound with id 264028 [63/150]
# Downloading sound with id 264029 [64/150]
# Downloading sound with id 264030 [65/150]
# Downloading sound with id 653797 [66/150]
# Downloading sound with id 657654 [67/150]
# Downloading sound with id 658332 [68/150]
# Downloading sound with id 656130 [69/150]
# Downloading sound with id 659016 [70/150]
# Downloading sound with id 655080 [71/150]
# Downloading sound with id 653713 [72/150]
# Downloading sound with id 657561 [73/150]
# Downloading sound with id 658580 [74/150]
# Downloading sound with id 655187 [75/150]
# Downloading sound with id 655819 [76/150]
# Downloading sound with id 657575 [77/150]
# Downloading sound with id 432208 [78/150]
# Downloading sound with id 394188 [79/150]
# Downloading sound with id 181734 [80/150]
# Downloading sound with id 659312 [81/150]
# Downloading sound with id 361636 [82/150]
# Downloading sound with id 554903 [83/150]
# Downloading sound with id 361211 [84/150]
# Downloading sound with id 494069 [85/150]
# Downloading sound with id 515598 [86/150]
# Downloading sound with id 540831 [87/150]
# Downloading sound with id 431488 [88/150]
# Downloading sound with id 432676 [89/150]
# Downloading sound with id 472121 [90/150]
# Downloading sound with id 595243 [91/150]
# Downloading sound with id 595817 [92/150]
# Downloading sound with id 595248 [93/150]
# Downloading sound with id 607056 [94/150]
# Downloading sound with id 564867 [95/150]
# Downloading sound with id 672578 [96/150]
# Downloading sound with id 324445 [97/150]
# Downloading sound with id 607922 [98/150]
# Downloading sound with id 388017 [99/150]
# Downloading sound with id 608345 [100/150]
# Downloading sound with id 607923 [101/150]
# Downloading sound with id 552037 [102/150]
# Downloading sound with id 541496 [103/150]
# Downloading sound with id 31130 [104/150]
# Downloading sound with id 31127 [105/150]
# Downloading sound with id 31129 [106/150]
# Downloading sound with id 336734 [107/150]
# Downloading sound with id 608347 [108/150]
# Downloading sound with id 595247 [109/150]
# Downloading sound with id 668626 [110/150]
# Downloading sound with id 658104 [111/150]
# Downloading sound with id 619847 [112/150]
# Downloading sound with id 536111 [113/150]
# Downloading sound with id 536078 [114/150]
# Downloading sound with id 669479 [115/150]
# Downloading sound with id 611192 [116/150]
# Downloading sound with id 607414 [117/150]
# Downloading sound with id 608140 [118/150]
# Downloading sound with id 608666 [119/150]
# Downloading sound with id 608138 [120/150]
# Downloading sound with id 564631 [121/150]
# Downloading sound with id 564661 [122/150]
# Downloading sound with id 553659 [123/150]
# Downloading sound with id 553685 [124/150]
# Downloading sound with id 553625 [125/150]
# Downloading sound with id 592100 [126/150]
# Downloading sound with id 594763 [127/150]
# Downloading sound with id 592638 [128/150]
# Downloading sound with id 570376 [129/150]
# Downloading sound with id 570375 [130/150]
# Downloading sound with id 579546 [131/150]
# Downloading sound with id 573375 [132/150]
# Downloading sound with id 576579 [133/150]
# Downloading sound with id 592659 [134/150]
# Downloading sound with id 536085 [135/150]
# Downloading sound with id 653132 [136/150]
# Downloading sound with id 607411 [137/150]
# Downloading sound with id 559324 [138/150]
# Downloading sound with id 554267 [139/150]
# Downloading sound with id 658852 [140/150]
# Downloading sound with id 536076 [141/150]
# Downloading sound with id 557106 [142/150]
# Downloading sound with id 561799 [143/150]
# Downloading sound with id 418500 [144/150]
# Downloading sound with id 633122 [145/150]
# Downloading sound with id 595244 [146/150]
# Downloading sound with id 668272 [147/150]
# Downloading sound with id 595874 [148/150]
# Downloading sound with id 637009 [149/150]
# Downloading sound with id 527771 [150/150]
# Saved DataFrame with 150 entries! dataframe_piano.csv
#                                                   name        username  \
# 0      Roland JX-8P - Slow Bass - D#3 (51D#2-30U1.aif)  modularsamples
# 1      Roland JX-8P - Bonus Bass - F1 (30F#0-JP7Q.aif)  modularsamples
# 2    Roland JX-8P - Sensitive Sync - C#2 (37C#1-30R...  modularsamples
# 3    Roland JX-8P - Sensitive Square - D3 (50D2-KRM...  modularsamples
# 4     Roland JX-8P - Proto Filter - E6 (88E5-0PN5.aif)  modularsamples
# ..                                                 ...             ...
# 145                                  Fireplace Burning    EminYILDIRIM
# 146                              Wierd Impact Designed    EminYILDIRIM
# 147                                   Forest Footsteps    EminYILDIRIM
# 148                   electric loading ramp open close      Garuda1982
# 149                              sparkling water maker      Garuda1982
#
#                                                license  \
# 0    http://creativecommons.org/publicdomain/zero/1.0/
# 1    http://creativecommons.org/publicdomain/zero/1.0/
# 2    http://creativecommons.org/publicdomain/zero/1.0/
# 3    http://creativecommons.org/publicdomain/zero/1.0/
# 4    http://creativecommons.org/publicdomain/zero/1.0/
# ..                                                 ...
# 145  http://creativecommons.org/publicdomain/zero/1.0/
# 146       https://creativecommons.org/licenses/by/4.0/
# 147  http://creativecommons.org/publicdomain/zero/1.0/
# 148       https://creativecommons.org/licenses/by/4.0/
# 149  http://creativecommons.org/publicdomain/zero/1.0/
#
#                                                   tags  freesound_id  \
# 0    [multisample, single-note, synthesizer, Roland...        309684
# 1    [multisample, single-note, synthesizer, Roland...        307802
# 2    [multisample, single-note, synthesizer, Roland...        308950
# 3    [multisample, single-note, synthesizer, Roland...        308829
# 4    [multisample, single-note, synthesizer, Roland...        308411
# ..                                                 ...           ...
# 145  [flames, burning, fire, stove, burn, flame, fi...        595244
# 146         [Impact, Hit, game, Designed, audio, Boom]        668272
# 147                  [walk, footsteps, forest, nature]        595874
# 148  [noise, door, electric, sfx, industry, loading...        637009
# 149  [bubbly, carbonated, co, liquid, underwater, d...        527771
#
#                              path
# 0     files/309684_2050105-hq.ogg
# 1     files/307802_2050105-hq.ogg
# 2     files/308950_2050105-hq.ogg
# 3     files/308829_2050105-hq.ogg
# 4     files/308411_2050105-hq.ogg
# ..                            ...
# 145  files/595244_10912485-hq.ogg
# 146  files/668272_10912485-hq.ogg
# 147  files/595874_10912485-hq.ogg
# 148   files/637009_2061858-hq.ogg
# 149   files/527771_2061858-hq.ogg
#
# [150 rows x 6 columns]
